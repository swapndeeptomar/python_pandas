# %% [markdown]
# Swiggy Sales Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Dataset Import

# %%
df=pd.read_excel('swiggy_data.xlsx')

# %% [markdown]
# Basic Data Overview

# %%
df.head(10)
# Out:
#        State       City Order Date           Restaurant Name  \
# 0  Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1  Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2  Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3  Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4  Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
# 5  Karnataka  Bengaluru 2025-07-08     Srinidhi Sagar Deluxe
# 6  Karnataka  Bengaluru 2025-01-21     Srinidhi Sagar Deluxe
# 7  Karnataka  Bengaluru 2025-04-13     Srinidhi Sagar Deluxe
# 8  Karnataka  Bengaluru 2025-05-02     Srinidhi Sagar Deluxe
# 9  Karnataka  Bengaluru 2025-07-30     Srinidhi Sagar Deluxe
#
#                Location            Category               Dish Name  \
# 0  Rajarajeshwari Nagar               Snack    Butter Murukku-200gm
# 1               Kengeri         Recommended              Badam Milk
# 2               Kengeri         Recommended          Chow Chow Bath
# ...

# %%
df.tail(10)
# Out:
#          State     City Order Date Restaurant Name Location Category  \
# 197420  Sikkim  Gangtok 2025-02-09  Mama's Kitchen  Gangtok    Momos
# 197421  Sikkim  Gangtok 2025-07-28  Mama's Kitchen  Gangtok    Momos
# 197422  Sikkim  Gangtok 2025-03-17  Mama's Kitchen  Gangtok    Momos
# 197423  Sikkim  Gangtok 2025-06-18  Mama's Kitchen  Gangtok    Momos
# 197424  Sikkim  Gangtok 2025-08-11  Mama's Kitchen  Gangtok    Momos
# 197425  Sikkim  Gangtok 2025-01-25  Mama's Kitchen  Gangtok    Momos
# 197426  Sikkim  Gangtok 2025-07-02  Mama's Kitchen  Gangtok    Momos
# 197427  Sikkim  Gangtok 2025-03-25  Mama's Kitchen  Gangtok    Momos
# 197428  Sikkim  Gangtok 2025-03-26  Mama's Kitchen  Gangtok    Momos
# 197429  Sikkim  Gangtok 2025-03-27  Mama's Kitchen  Gangtok    Momos
#
#                                                 Dish Name  Price (INR)  \
# 197420  Mushroom cheese steam momo                    ...        112.0
# ...

# %%
#Metadata rows and columns
df.shape
# Out:
# (197430, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197430 entries, 0 to 197429
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            197430 non-null  object
#  1   City             197430 non-null  object
#  2   Order Date       197430 non-null  datetime64[ns]
#  3   Restaurant Name  197430 non-null  object
#  4   Location         197430 non-null  object
#  5   Category         197430 non-null  object
#  6   Dish Name        197430 non-null  object
#  7   Price (INR)      197430 non-null  float64
#  8   Rating           197430 non-null  float64
#  9   Rating Count     197430 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 15.1+ MB

# %%
df.dtypes
# Out:
# State                      object
# City                       object
# Order Date         datetime64[ns]
# Restaurant Name            object
# Location                   object
# Category                   object
# Dish Name                  object
# Price (INR)               float64
# Rating                    float64
# Rating Count                int64
# dtype: object

# %%
df.describe()
# Out:
#                           Order Date    Price (INR)         Rating  \
# count                         197430  197430.000000  197430.000000
# mean   2025-05-01 19:41:20.996808960     268.512920       4.341582
# min              2025-01-01 00:00:00       0.950000       1.500000
# 25%              2025-03-01 00:00:00     139.000000       4.300000
# 50%              2025-05-02 00:00:00     229.000000       4.400000
# 75%              2025-07-01 00:00:00     329.000000       4.500000
# max              2025-08-31 00:00:00    8000.000000       5.000000
# std                              NaN     219.338363       0.422585
#
#         Rating Count
# count  197430.000000
# mean       28.321805
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%        15.000000
# max       999.000000
# std        87.542593

# %%
#Total Sales
total_sales=df['Price (INR)'].sum()
print("Total Sales of Swiggy is Rs",round(total_sales,2))
# Out:
# Total Sales of Swiggy is Rs 53012505.77

# %%
#Average Rating across all orders
avg_rating=df['Rating'].mean()
print("Average Rating across all orders is",round(avg_rating,2))
# Out:
# Average Rating across all orders is 4.34

# %%
# Average Order Value
avg_order_value=df['Price (INR)'].mean()
print("Average Order Value is Rs",round(avg_order_value,2))
# Out:
# Average Order Value is Rs 268.51

# %%
# Total Rating Count
ratings_count=df['Rating Count'].sum()
print("Total Rating Count is",ratings_count)
# Out:
# Total Rating Count is 5591574

# %%
#Total Orders in Dataset
total_orders=len(df)
print("Total Orders in Dataset is",total_orders)
# Out:
# Total Orders in Dataset is 197430

# %% [markdown]
# Visual Business Charts

# %%
#Monthly Sales trend
df['Order Date']=pd.to_datetime(df['Order Date'])
df['YearMonth']=df['Order Date'].dt.to_period("M").astype(str)
monthly_sales=df.groupby('YearMonth')["Price (INR)"].sum().reset_index()

plt.figure()
plt.plot(monthly_sales['YearMonth'],monthly_sales['Price (INR)'])
plt.xticks(rotation=45)
plt.xlabel('Year Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Trend')
plt.tight_layout()
plt.show()

# %%
df['DayName']=pd.to_datetime(df['Order Date']).dt.day_name()

daily_revenue=df.groupby('DayName')['Price (INR)'].sum().reindex(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])

plt.figure(figsize=(10,6))
colors = sns.color_palette('viridis', len(daily_revenue))
plt.bar(daily_revenue.index,daily_revenue.values, color=colors)
plt.title("Daily Revenue Trend (Mon-Sun)")
plt.xlabel("Day of Week")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)

for i, value in enumerate(daily_revenue.values):
    plt.text(i, value, f'Rs {value:,.0f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Total Sales by Food Type (Veg-NonVeg)
non_veg_keywords=[
"chicken","egg","fish","mutton","prawn","biryani",
"kabab","kebab","non-veg","non veg"
 ]

df["Food Category"]=np.where(
    df["Dish Name"].str.lower().str.contains("|".join(non_veg_keywords),na=False),
    "Non-Veg",
    "Veg")

# %%
food_revenue=(
    df.groupby("Food Category")['Price (INR)'].sum().reset_index()
)

# %%
fig=px.pie(
    food_revenue,
    values="Price (INR)",
    names="Food Category",
    hole=0.5,
    title="Total Sales by Food Type"
)
fig.update_traces(textinfo="percent+label",
                  pull=[0.05,0]
)
fig.update_layout(
    height=500,
    margin=dict(t=60,b=40,l=40,r=40)
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Total Sales by State
fig=px.bar(
    df.groupby("State",as_index=False)['Price (INR)'].sum()
    .sort_values(by="Price (INR)",ascending=False),
    x="Price (INR)",
    y="State",
    orientation='h',
    title="Total Sales by State"
)
fig.update_layout(height=600,yaxis=dict(autorange="reversed")
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Quarterly Performance Summary

df["Order_Date"] = pd.to_datetime(df["Order Date"])
df["Quarter"] = df["Order_Date"].dt.to_period("Q").astype(str)

quarterly_summary = (
    df.groupby("Quarter", as_index=False)
    .agg(
        Total_Sales=("Price (INR)", "sum"),
        Avg_Rating=("Rating", "mean"),
        Total_Orders=("Order_Date", "count")
    )
    .sort_values("Quarter")
)

quarterly_summary["Total_Sales"] = quarterly_summary["Total_Sales"].round(0)
quarterly_summary["Avg_Rating"] = quarterly_summary["Avg_Rating"].round(2)

quarterly_summary
# Out:
#   Quarter  Total_Sales  Avg_Rating  Total_Orders
# 0  2025Q1   19667822.0        4.34         73096
# 1  2025Q2   19902257.0        4.34         74163
# 2  2025Q3   13442427.0        4.34         50171

# %%
# Top 5 Cities by sales
top_5=(
    df.groupby("City")["Price (INR)"]
    .sum()
    .nlargest(5)
    .sort_values()
    .reset_index()
)

fig=px.bar(
    top_5,
    x="Price (INR)",
    y="City",
    orientation="h",
    title="Top 5 Cities by Sales"
)
fig.update_layout(height=600
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Order Week'] = df['Order Date'].dt.isocalendar().week.astype(int)
weekly_sales = df.groupby('Order Week')['Price (INR)'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(weekly_sales['Order Week'], weekly_sales['Price (INR)'], marker='o')
plt.title('Weekly Sales Fluctuation')
plt.xlabel('Week Number')
plt.ylabel('Total Sales (INR)')
plt.grid(True)
plt.xticks(weekly_sales['Order Week'])
plt.tight_layout()
plt.show()

# %%
df['Day Type'] = df['DayName'].apply(lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday')

weekend_vs_weekday_sales = df.groupby('Day Type')['Price (INR)'].sum().reset_index()

fig = px.bar(
    weekend_vs_weekday_sales,
    x='Day Type',
    y='Price (INR)',
    title='Sales Comparison: Weekday vs. Weekend',
    color='Day Type',
    color_discrete_map={'Weekday': 'skyblue', 'Weekend': 'salmon'}
)

fig.update_traces(texttemplate='Rs %{y:,.0f}', textposition='outside')
fig.update_layout(height=500, xaxis_title='Day Type', yaxis_title='Total Sales (INR)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
